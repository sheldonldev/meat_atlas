# %%
"""Modules"""

import urllib.request, urllib.parse, urllib.error
import requests
from bs4 import BeautifulSoup

import lxml
import re
import os
import time
import datetime
import chardet
import zipfile
from zipfile import ZipFile
import json
from io import BytesIO

from IPython.display import display

import matplotlib.pyplot as plt
import matplotlib.transforms
# %matplotlib inline

import folium
from PIL import Image


import numpy as np
import pandas as pd

pd.set_option('precision', 4)
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('max_colwidth',100)

def curl(url,path,mode='wb'):
    response = urllib.request.urlopen(url).read()
    with open(path, mode) as handle:
        handle.write(response)

# %%
""" DIRECTOR SETTINGS"""

# USDA_DOWNLOADS_XML = 'https://www.usda.gov/sites/default/files/documents/data.xml'



# what is the relevent path of root
root_where = '../../'
print('+++++++++ Atention ++++++++++')
print(f'The root is set as "{root_where}" relevent to this file.' )
print(f'If it is not right, you change this parameter where the parameter name is "root_where".' )
print('+++++++++++++++++++++++++++++')

LOCAL_ROOT = os.path.abspath(root_where)
DATA_BASE = os.path.join(LOCAL_ROOT, 'data')
print(f'Root director: {LOCAL_ROOT}')
print(f'Data director: {DATA_BASE}')

DATA_USDA = os.path.join(DATA_BASE, 'USDA')
USDA_meta = os.path.join(DATA_USDA, 'metadata')
USDA_description_path = USDA_meta+'/data.xml'
print(f'USDA data director: {DATA_USDA}')
print(f'USDA medadata director: {USDA_meta}')
print(f'USDA local description file: {USDA_description_path}')
# Out:
# +++++++++ Atention ++++++++++
# The root is set as "../../" relevent to this file.
# If it is not right, you change this parameter where the parameter name is "root_where".
# +++++++++++++++++++++++++++++
# Root director: /mnt/sda2/_hub/projects/GoodFood/meat-atlas
# Data director: /mnt/sda2/_hub/projects/GoodFood/meat-atlas/data
# USDA data director: /mnt/sda2/_hub/projects/GoodFood/meat-atlas/data/USDA
# USDA medadata director: /mnt/sda2/_hub/projects/GoodFood/meat-atlas/data/USDA/metadata
# USDA local description file: /mnt/sda2/_hub/projects/GoodFood/meat-atlas/data/USDA/metadata/data.xml

# %%
zf = ZipFile(f'{DATA_USDA}/psd_alldata_csv.zip')

data = pd.read_csv(zf.open(f'psd_alldata.csv'))


display(data.head())
display(data.tail())
# Out:
#    Commodity_Code   Commodity_Description Country_Code Country_Name  \
# 0          577400  Almonds, Shelled Basis           AF  Afghanistan
# 1          577400  Almonds, Shelled Basis           AF  Afghanistan
# 2          577400  Almonds, Shelled Basis           AF  Afghanistan
# 3          577400  Almonds, Shelled Basis           AF  Afghanistan
# 4          577400  Almonds, Shelled Basis           AF  Afghanistan
#
#    Market_Year  Calendar_Year  Month  Attribute_ID Attribute_Description  \
# 0         2010           2018     10            20      Beginning Stocks
# 1         2010           2018     10           125  Domestic Consumption
# 2         2010           2018     10           176         Ending Stocks
# 3         2010           2018     10            88               Exports
# 4         2010           2018     10            57               Imports
#
#    Unit_ID Unit_Description  Value
# 0       21             (MT)    0.0
# 1       21             (MT)    0.0
# 2       21             (MT)    0.0
# 3       21             (MT)    0.0
# 4       21             (MT)    0.0
#          Commodity_Code Commodity_Description Country_Code Country_Name  \
# 1873742          410000                 Wheat           RH     Zimbabwe
# 1873743          410000                 Wheat           RH     Zimbabwe
# 1873744          410000                 Wheat           RH     Zimbabwe
# 1873745          410000                 Wheat           RH     Zimbabwe
# 1873746          410000                 Wheat           RH     Zimbabwe
#
#          Market_Year  Calendar_Year  Month  Attribute_ID  \
# 1873742         2019           2019     12            86
# 1873743         2019           2019     12           113
# 1873744         2019           2019     12            84
# 1873745         2019           2019     12            81
# 1873746         2019           2019     12           184
#
#         Attribute_Description  Unit_ID Unit_Description  Value
# 1873742          Total Supply        8        (1000 MT)  350.0
# 1873743            TY Exports        8        (1000 MT)    0.0
# 1873744     TY Imp. from U.S.        8        (1000 MT)    0.0
# 1873745            TY Imports        8        (1000 MT)  200.0
# 1873746                 Yield       26          (MT/HA)    4.0

# %%
data.columns
# Out:
# Index(['Commodity_Code', 'Commodity_Description', 'Country_Code',
#        'Country_Name', 'Market_Year', 'Calendar_Year', 'Month', 'Attribute_ID',
#        'Attribute_Description', 'Unit_ID', 'Unit_Description', 'Value'],
#       dtype='object')

# %%
data.groupby(['Commodity_Description']).count()
# Out:
#                               Commodity_Code  Country_Code  Country_Name  \
# Commodity_Description
# Almonds, Shelled Basis                  6432          6432          6432
# Animal Numbers, Cattle                 36120         36120         36120
# Animal Numbers, Swine                  25380         25380         25380
# Apples, Fresh                          30570         30570         30570
# Barley                                 55785         55785         55785
# Cherries (Sweet&Sour), Fresh            7910          7910          7910
# Coffee, Green                          72751         72751         72751
# Corn                                  100425        100425        100425
# Cotton                                 89310         89310         89310
# Dairy, Butter                          14949         14949         14949
# Dairy, Cheese                          15084         15084         15084
# Dairy, Dry Whole Milk Powder            7254          7254          7254
# Dairy, Milk, Fluid                     21444         21444         21444
# Dairy, Milk, Nonfat Dry                15768         15768         15768
# Grapefruit, Fresh                       6069          6069          6069
# Grapes, Fresh Table                     7479          7479          7479
# Lemons/Limes, Fresh                     6741          6741          6741
# Meal, Copra                            19544         19544         19544
# Meal, Cottonseed                       35490         35490         35490
# Meal, Fish                             26992         26992         26992
# Meal, Palm Kernel                      20580         20580         20580
# Meal, Peanut                           22778         22778         22778
# Meal, Rapeseed                         25200         25200         25200
# Meal, Soybean                          58044         57904         58044
# Meal, Soybean (Local)                   1568          1568          1568
# Meal, Sunflowerseed                    23814         23814         23814
# Meat, Beef and Veal                    29856         29856         29856
# Meat, Chicken                           9090          9090          9090
# Meat, Swine                            26564         26430         26564
# Millet                                 42375         42375         42375
# Mixed Grain                             5835          5835          5835
# Oats                                   28800         28800         28800
# Oil, Coconut                           25974         25974         25974
# Oil, Cottonseed                        32774         32774         32774
# Oil, Olive                             13596         13596         13596
# Oil, Palm                              47008         47008         47008
# Oil, Palm Kernel                       25298         25298         25298
# Oil, Peanut                            21814         21814         21814
# Oil, Rapeseed                          27066         27066         27066
# Oil, Soybean                           54197         54197         54197
# Oil, Soybean (Local)                    1456          1456          1456
# Oil, Sunflowerseed                     29991         29991         29991
# Oilseed, Copra                         20196         20196         20196
# Oilseed, Cottonseed                    28994         28994         28994
# Oilseed, Palm Kernel                   18720         18720         18720
# Oilseed, Peanut                        34489         34489         34489
# Oilseed, Rapeseed                      21996         21996         21996
# Oilseed, Soybean                       42679         42679         42679
# Oilseed, Soybean (Local)                1456          1456          1456
# Oilseed, Sunflowerseed                 22243         22243         22243
# Orange Juice                            4824          4824          4824
# Oranges, Fresh                          9485          9485          9485
# Peaches & Nectarines, Fresh             9060          9060          9060
# Pears, Fresh                           14600         14600         14600
# Pistachios, Inshell Basis               4896          4896          4896
# Poultry, Meat, Broiler                 23198         23198         23198
# Poultry, Meat, Turkey                   8769          8769          8769
# Rice, Milled                          102045        102045        102045
# Rye                                    21060         21060         21060
# Sorghum                                56115         56115         56115
# Sugar, Centrifugal                    136368        135600        136368
# Tangerines/Mandarins, Fresh             7238          7238          7238
# Walnuts, Inshell Basis                  6896          6896          6896
# Wheat                                 103245        103245        103245
#
#                               Market_Year  Calendar_Year   Month  \
# Commodity_Description
# Almonds, Shelled Basis               6432           6432    6432
# Animal Numbers, Cattle              36120          36120   36120
# Animal Numbers, Swine               25380          25380   25380
# Apples, Fresh                       30570          30570   30570
# Barley                              55785          55785   55785
# Cherries (Sweet&Sour), Fresh         7910           7910    7910
# Coffee, Green                       72751          72751   72751
# Corn                               100425         100425  100425
# Cotton                              89310          89310   89310
# Dairy, Butter                       14949          14949   14949
# Dairy, Cheese                       15084          15084   15084
# Dairy, Dry Whole Milk Powder         7254           7254    7254
# Dairy, Milk, Fluid                  21444          21444   21444
# Dairy, Milk, Nonfat Dry             15768          15768   15768
# Grapefruit, Fresh                    6069           6069    6069
# Grapes, Fresh Table                  7479           7479    7479
# Lemons/Limes, Fresh                  6741           6741    6741
# Meal, Copra                         19544          19544   19544
# Meal, Cottonseed                    35490          35490   35490
# Meal, Fish                          26992          26992   26992
# Meal, Palm Kernel                   20580          20580   20580
# Meal, Peanut                        22778          22778   22778
# Meal, Rapeseed                      25200          25200   25200
# Meal, Soybean                       58044          58044   58044
# Meal, Soybean (Local)                1568           1568    1568
# Meal, Sunflowerseed                 23814          23814   23814
# Meat, Beef and Veal                 29856          29856   29856
# Meat, Chicken                        9090           9090    9090
# Meat, Swine                         26564          26564   26564
# Millet                              42375          42375   42375
# Mixed Grain                          5835           5835    5835
# Oats                                28800          28800   28800
# Oil, Coconut                        25974          25974   25974
# Oil, Cottonseed                     32774          32774   32774
# Oil, Olive                          13596          13596   13596
# Oil, Palm                           47008          47008   47008
# Oil, Palm Kernel                    25298          25298   25298
# Oil, Peanut                         21814          21814   21814
# Oil, Rapeseed                       27066          27066   27066
# Oil, Soybean                        54197          54197   54197
# Oil, Soybean (Local)                 1456           1456    1456
# Oil, Sunflowerseed                  29991          29991   29991
# Oilseed, Copra                      20196          20196   20196
# Oilseed, Cottonseed                 28994          28994   28994
# Oilseed, Palm Kernel                18720          18720   18720
# Oilseed, Peanut                     34489          34489   34489
# Oilseed, Rapeseed                   21996          21996   21996
# Oilseed, Soybean                    42679          42679   42679
# Oilseed, Soybean (Local)             1456           1456    1456
# Oilseed, Sunflowerseed              22243          22243   22243
# Orange Juice                         4824           4824    4824
# Oranges, Fresh                       9485           9485    9485
# Peaches & Nectarines, Fresh          9060           9060    9060
# Pears, Fresh                        14600          14600   14600
# Pistachios, Inshell Basis            4896           4896    4896
# Poultry, Meat, Broiler              23198          23198   23198
# Poultry, Meat, Turkey                8769           8769    8769
# Rice, Milled                       102045         102045  102045
# Rye                                 21060          21060   21060
# Sorghum                             56115          56115   56115
# Sugar, Centrifugal                 136368         136368  136368
# Tangerines/Mandarins, Fresh          7238           7238    7238
# Walnuts, Inshell Basis               6896           6896    6896
# Wheat                              103245         103245  103245
#
#                               Attribute_ID  Attribute_Description  Unit_ID  \
# Commodity_Description
# Almonds, Shelled Basis                6432                   6432     6432
# Animal Numbers, Cattle               36120                  36120    36120
# Animal Numbers, Swine                25380                  25380    25380
# Apples, Fresh                        30570                  30570    30570
# Barley                               55785                  55785    55785
# Cherries (Sweet&Sour), Fresh          7910                   7910     7910
# Coffee, Green                        72751                  72751    72751
# Corn                                100425                 100425   100425
# Cotton                               89310                  89310    89310
# Dairy, Butter                        14949                  14949    14949
# Dairy, Cheese                        15084                  15084    15084
# Dairy, Dry Whole Milk Powder          7254                   7254     7254
# Dairy, Milk, Fluid                   21444                  21444    21444
# Dairy, Milk, Nonfat Dry              15768                  15768    15768
# Grapefruit, Fresh                     6069                   6069     6069
# Grapes, Fresh Table                   7479                   7479     7479
# Lemons/Limes, Fresh                   6741                   6741     6741
# Meal, Copra                          19544                  19544    19544
# Meal, Cottonseed                     35490                  35490    35490
# Meal, Fish                           26992                  26992    26992
# Meal, Palm Kernel                    20580                  20580    20580
# Meal, Peanut                         22778                  22778    22778
# Meal, Rapeseed                       25200                  25200    25200
# Meal, Soybean                        58044                  58044    58044
# Meal, Soybean (Local)                 1568                   1568     1568
# Meal, Sunflowerseed                  23814                  23814    23814
# Meat, Beef and Veal                  29856                  29856    29856
# Meat, Chicken                         9090                   9090     9090
# Meat, Swine                          26564                  26564    26564
# Millet                               42375                  42375    42375
# Mixed Grain                           5835                   5835     5835
# Oats                                 28800                  28800    28800
# Oil, Coconut                         25974                  25974    25974
# Oil, Cottonseed                      32774                  32774    32774
# Oil, Olive                           13596                  13596    13596
# Oil, Palm                            47008                  47008    47008
# Oil, Palm Kernel                     25298                  25298    25298
# Oil, Peanut                          21814                  21814    21814
# Oil, Rapeseed                        27066                  27066    27066
# Oil, Soybean                         54197                  54197    54197
# Oil, Soybean (Local)                  1456                   1456     1456
# Oil, Sunflowerseed                   29991                  29991    29991
# Oilseed, Copra                       20196                  20196    20196
# Oilseed, Cottonseed                  28994                  28994    28994
# Oilseed, Palm Kernel                 18720                  18720    18720
# Oilseed, Peanut                      34489                  34489    34489
# Oilseed, Rapeseed                    21996                  21996    21996
# Oilseed, Soybean                     42679                  42679    42679
# Oilseed, Soybean (Local)              1456                   1456     1456
# Oilseed, Sunflowerseed               22243                  22243    22243
# Orange Juice                          4824                   4824     4824
# Oranges, Fresh                        9485                   9485     9485
# Peaches & Nectarines, Fresh           9060                   9060     9060
# Pears, Fresh                         14600                  14600    14600
# Pistachios, Inshell Basis             4896                   4896     4896
# Poultry, Meat, Broiler               23198                  23198    23198
# Poultry, Meat, Turkey                 8769                   8769     8769
# Rice, Milled                        102045                 102045   102045
# Rye                                  21060                  21060    21060
# Sorghum                              56115                  56115    56115
# Sugar, Centrifugal                  136368                 136368   136368
# Tangerines/Mandarins, Fresh           7238                   7238     7238
# Walnuts, Inshell Basis                6896                   6896     6896
# Wheat                               103245                 103245   103245
#
#                               Unit_Description   Value
# Commodity_Description
# Almonds, Shelled Basis                    6432    6432
# Animal Numbers, Cattle                   36120   36120
# Animal Numbers, Swine                    25380   25380
# Apples, Fresh                            30570   30570
# Barley                                   55785   55785
# Cherries (Sweet&Sour), Fresh              7910    7910
# Coffee, Green                            72751   72751
# Corn                                    100425  100425
# Cotton                                   89310   89310
# Dairy, Butter                            14949   14949
# Dairy, Cheese                            15084   15084
# Dairy, Dry Whole Milk Powder              7254    7254
# Dairy, Milk, Fluid                       21444   21444
# Dairy, Milk, Nonfat Dry                  15768   15768
# Grapefruit, Fresh                         6069    6069
# Grapes, Fresh Table                       7479    7479
# Lemons/Limes, Fresh                       6741    6741
# Meal, Copra                              19544   19544
# Meal, Cottonseed                         35490   35490
# Meal, Fish                               26992   26992
# Meal, Palm Kernel                        20580   20580
# Meal, Peanut                             22778   22778
# Meal, Rapeseed                           25200   25200
# Meal, Soybean                            58044   58044
# Meal, Soybean (Local)                     1568    1568
# Meal, Sunflowerseed                      23814   23814
# Meat, Beef and Veal                      29856   29856
# Meat, Chicken                             9090    9090
# Meat, Swine                              26564   26564
# Millet                                   42375   42375
# Mixed Grain                               5835    5835
# Oats                                     28800   28800
# Oil, Coconut                             25974   25974
# Oil, Cottonseed                          32774   32774
# Oil, Olive                               13596   13596
# Oil, Palm                                47008   47008
# Oil, Palm Kernel                         25298   25298
# Oil, Peanut                              21814   21814
# Oil, Rapeseed                            27066   27066
# Oil, Soybean                             54197   54197
# Oil, Soybean (Local)                      1456    1456
# Oil, Sunflowerseed                       29991   29991
# Oilseed, Copra                           20196   20196
# Oilseed, Cottonseed                      28994   28994
# Oilseed, Palm Kernel                     18720   18720
# Oilseed, Peanut                          34489   34489
# Oilseed, Rapeseed                        21996   21996
# Oilseed, Soybean                         42679   42679
# Oilseed, Soybean (Local)                  1456    1456
# Oilseed, Sunflowerseed                   22243   22243
# Orange Juice                              4824    4824
# Oranges, Fresh                            9485    9485
# Peaches & Nectarines, Fresh               9060    9060
# Pears, Fresh                             14600   14600
# Pistachios, Inshell Basis                 4896    4896
# Poultry, Meat, Broiler                   23198   23198
# Poultry, Meat, Turkey                     8769    8769
# Rice, Milled                            102045  102045
# Rye                                      21060   21060
# Sorghum                                  56115   56115
# Sugar, Centrifugal                      136368  136368
# Tangerines/Mandarins, Fresh               7238    7238
# Walnuts, Inshell Basis                    6896    6896
# Wheat                                   103245  103245
